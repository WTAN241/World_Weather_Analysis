# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90,high=90,size=2000)
lngs=np.random.uniform(low=-180,high=180,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f186aa03fc9f35ac9338a77c0bfe069

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City":city.title(),
                          "Country": city_country,
                         "Lat":city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed":city_wind,
                         "Current Description":city_weather_description})

# If an error is experienced, skip the city.   
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | turukhansk
# Processing Record 3 of Set 1 | tlahualilo
# City not found. Skipping...
# Processing Record 4 of Set 1 | carutapera
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | zaplavnoye
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | tondano
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | guarda
# Processing Record 15 of Set 1 | broken hill
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | aklavik
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | henties bay
# Processing Record 21 of Set 1 | naze
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | samastipur
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | venezuela
# Processing Record 29 of Set 1 | mount isa
# Processing Record 30 of Set 1 | aquiraz
# Processing Record 31 of Set 1 | sayla
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | sorland
# Processing Record 41 of Set 1 | shingu
# Processing Record 42 of Set 1 | salta
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | murgab
# Processing Record 45 of Set 1 | portland
# Processing Record 46 of Set 1 | kahului
# Processing Record 47 of Set 1 | campoverde
# Processing Record 48 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 1 | marrakesh
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | palmer
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | kaitangata
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | eidfjord
# Processing Record 9 of Set 2 | atar
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | schneverdingen
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | fossano
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | inirida
# Processing Record 21 of Set 2 | pangnirtung
# Processing Record 22 of Set 2 | wahiawa
# Processing Record 23 of Set 2 | vila velha
# Processing Record 24 of Set 2 | haimen
# Processing Record 25 of Set 2 | road town
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | qaqortoq
# Processing Record 28 of Set 2 | shumerlya
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | tarime
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | bhatkal
# Processing Record 33 of Set 2 | lazaro cardenas
# Processing Record 34 of Set 2 | bosaso
# Processing Record 35 of Set 2 | fortuna
# Processing Record 36 of Set 2 | robertson
# Processing Record 37 of Set 2 | cap malheureux
# Processing Record 38 of Set 2 | kang
# Processing Record 39 of Set 2 | fort nelson
# Processing Record 40 of Set 2 | sawtell
# Processing Record 41 of Set 2 | pec
# Processing Record 42 of Set 2 | olinda
# Processing Record 43 of Set 2 | kavaratti
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | sesheke
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | nuuk
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | taoudenni
# Processing Record 3 of Set 3 | ivanava
# Processing Record 4 of Set 3 | santa cecilia
# Processing Record 5 of Set 3 | porto novo
# Processing Record 6 of Set 3 | axim
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | ano mera
# Processing Record 10 of Set 3 | ondjiva
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | bouillante
# Processing Record 13 of Set 3 | busselton
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | tolaga bay
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | lowestoft
# Processing Record 20 of Set 3 | barkot
# Processing Record 21 of Set 3 | tornio
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | poum
# Processing Record 25 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 3 | venice
# Processing Record 27 of Set 3 | petropavlovka
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | mumford
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | mount gambier
# Processing Record 34 of Set 3 | domoni
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | matata
# Processing Record 37 of Set 3 | richards bay
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | kirakira
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | guilin
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | shieli
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | hualmay
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | yerbogachen
# Processing Record 2 of Set 4 | nikel
# Processing Record 3 of Set 4 | maniitsoq
# Processing Record 4 of Set 4 | north bend
# Processing Record 5 of Set 4 | vuktyl
# Processing Record 6 of Set 4 | labis
# Processing Record 7 of Set 4 | boulder
# Processing Record 8 of Set 4 | kangaatsiaq
# Processing Record 9 of Set 4 | samarai
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | lovington
# Processing Record 14 of Set 4 | serov
# Processing Record 15 of Set 4 | avera
# Processing Record 16 of Set 4 | boyolangu
# Processing Record 17 of Set 4 | dombarovskiy
# Processing Record 18 of Set 4 | hami
# Processing Record 19 of Set 4 | simpang
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | hilo
# Processing Record 24 of Set 4 | tigil
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | ixtapa
# Processing Record 28 of Set 4 | mus
# Processing Record 29 of Set 4 | kyakhta
# Processing Record 30 of Set 4 | tuy hoa
# Processing Record 31 of Set 4 | kamina
# Processing Record 32 of Set 4 | wukari
# Processing Record 33 of Set 4 | nikolskoye
# Processing Record 34 of Set 4 | camopi
# Processing Record 35 of Set 4 | necochea
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | riberalta
# Processing Record 38 of Set 4 | marapanim
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | coihueco
# Processing Record 41 of Set 4 | nehe
# Processing Record 42 of Set 4 | hollister
# Processing Record 43 of Set 4 | stupino
# Processing Record 44 of Set 4 | sasaram
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | cape town
# Processing Record 47 of Set 4 | tuktoyaktuk
# Processing Record 48 of Set 4 | les cayes
# Processing Record 49 of Set 4 | itarema
# Processing Record 50 of Set 4 | coquimbo
# Processing Record 1 of Set 5 | oistins
# Processing Record 2 of Set 5 | pemangkat
# Processing Record 3 of Set 5 | pangkalanbuun
# Processing Record 4 of Set 5 | grindavik
# Processing Record 5 of Set 5 | okhotsk
# Processing Record 6 of Set 5 | pitiquito
# Processing Record 7 of Set 5 | huarmey
# Processing Record 8 of Set 5 | havelock
# Processing Record 9 of Set 5 | kismayo
# Processing Record 10 of Set 5 | veraval
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | santa maria
# Processing Record 13 of Set 5 | puerto escondido
# Processing Record 14 of Set 5 | vostochnyy
# Processing Record 15 of Set 5 | goderich
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | biu
# Processing Record 18 of Set 5 | zyryanka
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | shaoguan
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | sulangan
# Processing Record 24 of Set 5 | saravena
# Processing Record 25 of Set 5 | tandur
# Processing Record 26 of Set 5 | balkanabat
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | lake havasu city
# Processing Record 30 of Set 5 | reo
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | kingaroy
# Processing Record 33 of Set 5 | vaini
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | rafai
# Processing Record 36 of Set 5 | tamandare
# Processing Record 37 of Set 5 | tazovskiy
# Processing Record 38 of Set 5 | calabar
# Processing Record 39 of Set 5 | tahe
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | jose de freitas
# Processing Record 42 of Set 5 | aktau
# Processing Record 43 of Set 5 | cajaruro
# Processing Record 44 of Set 5 | abu dhabi
# Processing Record 45 of Set 5 | bandarbeyla
# Processing Record 46 of Set 5 | adrar
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | gumdag
# Processing Record 49 of Set 5 | amposta
# Processing Record 50 of Set 5 | lasa
# Processing Record 1 of Set 6 | ericeira
# Processing Record 2 of Set 6 | pierre
# Processing Record 3 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 6 | abalak
# Processing Record 5 of Set 6 | lvovskoye
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | areosa
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | kenai
# Processing Record 10 of Set 6 | ekhabi
# Processing Record 11 of Set 6 | arauca
# Processing Record 12 of Set 6 | sur
# Processing Record 13 of Set 6 | schoonhoven
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | kristiinankaupunki
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | sinjar
# Processing Record 18 of Set 6 | marsh harbour
# Processing Record 19 of Set 6 | port elizabeth
# Processing Record 20 of Set 6 | binga
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | mantua
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | noumea
# Processing Record 25 of Set 6 | aldan
# Processing Record 26 of Set 6 | paamiut
# Processing Record 27 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 6 | pombas
# Processing Record 29 of Set 6 | gornopravdinsk
# Processing Record 30 of Set 6 | bull savanna
# Processing Record 31 of Set 6 | bilma
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | norman wells
# Processing Record 34 of Set 6 | bodden town
# Processing Record 35 of Set 6 | diveyevo
# Processing Record 36 of Set 6 | yulara
# Processing Record 37 of Set 6 | aksarka
# Processing Record 38 of Set 6 | kloulklubed
# Processing Record 39 of Set 6 | pacific grove
# Processing Record 40 of Set 6 | sinnamary
# Processing Record 41 of Set 6 | gasa
# Processing Record 42 of Set 6 | yenangyaung
# Processing Record 43 of Set 6 | bara
# Processing Record 44 of Set 6 | dhidhdhoo
# Processing Record 45 of Set 6 | katherine
# Processing Record 46 of Set 6 | biak
# Processing Record 47 of Set 6 | san policarpo
# Processing Record 48 of Set 6 | slave lake
# Processing Record 49 of Set 6 | messina
# Processing Record 50 of Set 6 | beringovskiy
# Processing Record 1 of Set 7 | pital
# Processing Record 2 of Set 7 | muisne
# Processing Record 3 of Set 7 | suoyarvi
# Processing Record 4 of Set 7 | aasiaat
# Processing Record 5 of Set 7 | ribeira grande
# Processing Record 6 of Set 7 | tekirdag
# Processing Record 7 of Set 7 | maceio
# Processing Record 8 of Set 7 | kilindoni
# Processing Record 9 of Set 7 | riviere-au-renard
# Processing Record 10 of Set 7 | karwar
# Processing Record 11 of Set 7 | lusambo
# Processing Record 12 of Set 7 | mahibadhoo
# Processing Record 13 of Set 7 | basco
# Processing Record 14 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 7 | mujiayingzi
# Processing Record 16 of Set 7 | pundaguitan
# Processing Record 17 of Set 7 | antsohihy
# Processing Record 18 of Set 7 | kayerkan
# Processing Record 19 of Set 7 | puerto ayacucho
# Processing Record 20 of Set 7 | chenzhou
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | san patricio
# Processing Record 23 of Set 7 | price
# Processing Record 24 of Set 7 | nyurba
# Processing Record 25 of Set 7 | muros
# Processing Record 26 of Set 7 | bonfim
# Processing Record 27 of Set 7 | komsomolskiy
# Processing Record 28 of Set 7 | kieta
# Processing Record 29 of Set 7 | kavieng
# Processing Record 30 of Set 7 | bardiyah
# Processing Record 31 of Set 7 | perbaungan
# Processing Record 32 of Set 7 | isangel
# Processing Record 33 of Set 7 | general pico
# Processing Record 34 of Set 7 | zavitinsk
# Processing Record 35 of Set 7 | agirish
# Processing Record 36 of Set 7 | hohhot
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | chifeng
# Processing Record 39 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 7 | aki
# Processing Record 41 of Set 7 | lorengau
# Processing Record 42 of Set 7 | sept-iles
# Processing Record 43 of Set 7 | kurilsk
# Processing Record 44 of Set 7 | jinchang
# Processing Record 45 of Set 7 | ambilobe
# Processing Record 46 of Set 7 | belaya gora
# Processing Record 47 of Set 7 | scarborough
# Processing Record 48 of Set 7 | erdenet
# Processing Record 49 of Set 7 | ban dung
# Processing Record 50 of Set 7 | springbok
# Processing Record 1 of Set 8 | kirando
# Processing Record 2 of Set 8 | vanavara
# Processing Record 3 of Set 8 | bo rai
# Processing Record 4 of Set 8 | nemuro
# Processing Record 5 of Set 8 | wanning
# Processing Record 6 of Set 8 | tambo
# Processing Record 7 of Set 8 | apac
# Processing Record 8 of Set 8 | phan thiet
# Processing Record 9 of Set 8 | lavrentiya
# Processing Record 10 of Set 8 | kipini
# Processing Record 11 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 8 | kautokeino
# Processing Record 13 of Set 8 | namwala
# Processing Record 14 of Set 8 | caravelas
# Processing Record 15 of Set 8 | khorol
# Processing Record 16 of Set 8 | karmala
# Processing Record 17 of Set 8 | bamako
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | morondava
# Processing Record 20 of Set 8 | calatayud
# Processing Record 21 of Set 8 | beisfjord
# Processing Record 22 of Set 8 | shenjiamen
# Processing Record 23 of Set 8 | develi
# Processing Record 24 of Set 8 | gizo
# Processing Record 25 of Set 8 | ngunguru
# Processing Record 26 of Set 8 | leeton
# Processing Record 27 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 8 | santo nino
# Processing Record 30 of Set 8 | arica
# Processing Record 31 of Set 8 | husavik
# Processing Record 32 of Set 8 | payakumbuh
# Processing Record 33 of Set 8 | knysna
# Processing Record 34 of Set 8 | lianzhou
# Processing Record 35 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 8 | sindor
# Processing Record 37 of Set 8 | havoysund
# Processing Record 38 of Set 8 | plettenberg bay
# Processing Record 39 of Set 8 | manama
# Processing Record 40 of Set 8 | jalu
# Processing Record 41 of Set 8 | klaksvik
# Processing Record 42 of Set 8 | dubbo
# Processing Record 43 of Set 8 | kabalo
# Processing Record 44 of Set 8 | gladstone
# Processing Record 45 of Set 8 | east wenatchee bench
# Processing Record 46 of Set 8 | trinidad
# Processing Record 47 of Set 8 | santiago
# Processing Record 48 of Set 8 | san vicente
# Processing Record 49 of Set 8 | najran
# Processing Record 50 of Set 8 | volodarka
# Processing Record 1 of Set 9 | beruwala
# Processing Record 2 of Set 9 | laguna
# Processing Record 3 of Set 9 | xiaoweizhai
# Processing Record 4 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 9 | tanout
# Processing Record 6 of Set 9 | chapais
# Processing Record 7 of Set 9 | cherskiy
# Processing Record 8 of Set 9 | honiara
# Processing Record 9 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | a
# City not found. Skipping...
# Processing Record 13 of Set 9 | andenes
# Processing Record 14 of Set 9 | lawton
# Processing Record 15 of Set 9 | dunedin
# Processing Record 16 of Set 9 | businga
# Processing Record 17 of Set 9 | fort saint james
# Processing Record 18 of Set 9 | tambun
# Processing Record 19 of Set 9 | sukumo
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | sabang
# Processing Record 22 of Set 9 | smithers
# Processing Record 23 of Set 9 | mehamn
# Processing Record 24 of Set 9 | denia
# Processing Record 25 of Set 9 | ferkessedougou
# Processing Record 26 of Set 9 | yatou
# Processing Record 27 of Set 9 | la paz
# Processing Record 28 of Set 9 | tabas
# Processing Record 29 of Set 9 | uaua
# Processing Record 30 of Set 9 | las juntas
# Processing Record 31 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 9 | shache
# Processing Record 33 of Set 9 | korla
# Processing Record 34 of Set 9 | ambulu
# Processing Record 35 of Set 9 | opelika
# Processing Record 36 of Set 9 | cabra
# Processing Record 37 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 38 of Set 9 | sainte-marie
# Processing Record 39 of Set 9 | usinsk
# Processing Record 40 of Set 9 | sibolga
# Processing Record 41 of Set 9 | kudowa-zdroj
# Processing Record 42 of Set 9 | pimenta bueno
# Processing Record 43 of Set 9 | esil
# Processing Record 44 of Set 9 | salinopolis
# Processing Record 45 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 46 of Set 9 | fare
# Processing Record 47 of Set 9 | kokopo
# Processing Record 48 of Set 9 | pachperwa
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | namatanai
# Processing Record 1 of Set 10 | trapani
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | arauco
# Processing Record 4 of Set 10 | mandalgovi
# Processing Record 5 of Set 10 | khandyga
# Processing Record 6 of Set 10 | egvekinot
# Processing Record 7 of Set 10 | calabozo
# Processing Record 8 of Set 10 | zhigansk
# Processing Record 9 of Set 10 | tena
# Processing Record 10 of Set 10 | pyshchug
# Processing Record 11 of Set 10 | abbeville
# Processing Record 12 of Set 10 | ust-maya
# Processing Record 13 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 10 | bilibino
# Processing Record 15 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 10 | vologda
# Processing Record 17 of Set 10 | sarakhs
# Processing Record 18 of Set 10 | stornoway
# Processing Record 19 of Set 10 | hofn
# Processing Record 20 of Set 10 | gorontalo
# Processing Record 21 of Set 10 | bowen
# Processing Record 22 of Set 10 | lima
# Processing Record 23 of Set 10 | paita
# Processing Record 24 of Set 10 | saint-joseph
# Processing Record 25 of Set 10 | kutum
# Processing Record 26 of Set 10 | le port
# Processing Record 27 of Set 10 | buala
# Processing Record 28 of Set 10 | ust-nera
# Processing Record 29 of Set 10 | rabo de peixe
# Processing Record 30 of Set 10 | pervomayskoye
# Processing Record 31 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 10 | vestmannaeyjar
# Processing Record 33 of Set 10 | strelka
# Processing Record 34 of Set 10 | shenkursk
# Processing Record 35 of Set 10 | port said
# Processing Record 36 of Set 10 | kedgwick
# Processing Record 37 of Set 10 | nova ushytsya
# Processing Record 38 of Set 10 | mbanza-ngungu
# Processing Record 39 of Set 10 | sao raimundo das mangabeiras
# Processing Record 40 of Set 10 | cidreira
# Processing Record 41 of Set 10 | skelleftea
# Processing Record 42 of Set 10 | inhuma
# Processing Record 43 of Set 10 | muyezerskiy
# Processing Record 44 of Set 10 | half moon bay
# Processing Record 45 of Set 10 | teya
# Processing Record 46 of Set 10 | mananjary
# Processing Record 47 of Set 10 | kuusamo
# Processing Record 48 of Set 10 | kazerun
# Processing Record 49 of Set 10 | padang
# Processing Record 50 of Set 10 | waipawa
# Processing Record 1 of Set 11 | sabha
# Processing Record 2 of Set 11 | lashio
# Processing Record 3 of Set 11 | banda aceh
# Processing Record 4 of Set 11 | shimoda
# Processing Record 5 of Set 11 | manzhouli
# Processing Record 6 of Set 11 | manavgat
# Processing Record 7 of Set 11 | cockburn town
# Processing Record 8 of Set 11 | acapulco
# Processing Record 9 of Set 11 | corn island
# Processing Record 10 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 11 | ruteng
# Processing Record 12 of Set 11 | winsum
# Processing Record 13 of Set 11 | chicama
# Processing Record 14 of Set 11 | kargasok
# Processing Record 15 of Set 11 | mopipi
# Processing Record 16 of Set 11 | olafsvik
# Processing Record 17 of Set 11 | srednekolymsk
# Processing Record 18 of Set 11 | lishui
# Processing Record 19 of Set 11 | jvari
# Processing Record 20 of Set 11 | kaliua
# Processing Record 21 of Set 11 | homer
# Processing Record 22 of Set 11 | pevek
# Processing Record 23 of Set 11 | iskilip
# Processing Record 24 of Set 11 | codrington
# Processing Record 25 of Set 11 | leshukonskoye
# Processing Record 26 of Set 11 | bairiki
# Processing Record 27 of Set 11 | viisoara
# Processing Record 28 of Set 11 | awjilah
# Processing Record 29 of Set 11 | nkhata bay
# Processing Record 30 of Set 11 | batagay-alyta
# Processing Record 31 of Set 11 | natal
# Processing Record 32 of Set 11 | burgeo
# Processing Record 33 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 34 of Set 11 | amahai
# Processing Record 35 of Set 11 | conceicao do araguaia
# Processing Record 36 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 11 | calvinia
# Processing Record 38 of Set 11 | tessalit
# Processing Record 39 of Set 11 | vrangel
# Processing Record 40 of Set 11 | hulan ergi
# Processing Record 41 of Set 11 | douglas
# Processing Record 42 of Set 11 | kidal
# Processing Record 43 of Set 11 | merauke
# Processing Record 44 of Set 11 | dhamtari
# Processing Record 45 of Set 11 | terrace
# Processing Record 46 of Set 11 | lubango
# Processing Record 47 of Set 11 | belyy yar
# Processing Record 48 of Set 11 | gimli
# Processing Record 49 of Set 11 | guntur
# Processing Record 50 of Set 11 | udachnyy
# Processing Record 1 of Set 12 | dalvik
# Processing Record 2 of Set 12 | trincomalee
# Processing Record 3 of Set 12 | moerai
# Processing Record 4 of Set 12 | grand gaube
# Processing Record 5 of Set 12 | nakamura
# Processing Record 6 of Set 12 | talnakh
# Processing Record 7 of Set 12 | puerto madryn
# Processing Record 8 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 9 of Set 12 | northam
# Processing Record 10 of Set 12 | nelson bay
# Processing Record 11 of Set 12 | tucupita
# Processing Record 12 of Set 12 | bisira
# Processing Record 13 of Set 12 | meridian
# Processing Record 14 of Set 12 | san joaquin
# Processing Record 15 of Set 12 | broome
# Processing Record 16 of Set 12 | tual
# Processing Record 17 of Set 12 | oktyabrskiy
# Processing Record 18 of Set 12 | moreira sales
# Processing Record 19 of Set 12 | liberal
# Processing Record 20 of Set 12 | kinlochleven
# Processing Record 21 of Set 12 | sarangani
# Processing Record 22 of Set 12 | salisbury
# Processing Record 23 of Set 12 | ust-koksa
# Processing Record 24 of Set 12 | blackwater
# Processing Record 25 of Set 12 | taywarah
# Processing Record 26 of Set 12 | lincolnwood
# Processing Record 27 of Set 12 | sobolevo
# Processing Record 28 of Set 12 | roald
# Processing Record 29 of Set 12 | okakarara
# Processing Record 30 of Set 12 | saint-augustin
# Processing Record 31 of Set 12 | dickinson
# Processing Record 32 of Set 12 | indianola
# Processing Record 33 of Set 12 | charters towers
# Processing Record 34 of Set 12 | yangambi
# Processing Record 35 of Set 12 | batemans bay
# Processing Record 36 of Set 12 | dandong
# Processing Record 37 of Set 12 | taos
# Processing Record 38 of Set 12 | seymchan
# Processing Record 39 of Set 12 | ostersund
# Processing Record 40 of Set 12 | mirnyy
# Processing Record 41 of Set 12 | playas
# Processing Record 42 of Set 12 | atasu
# Processing Record 43 of Set 12 | toamasina
# Processing Record 44 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 45 of Set 12 | verkhnyaya inta
# Processing Record 46 of Set 12 | gurupa
# Processing Record 47 of Set 12 | port keats
# Processing Record 48 of Set 12 | baykit
# Processing Record 49 of Set 12 | pontian kecil
# Processing Record 50 of Set 12 | linkoping
# Processing Record 1 of Set 13 | tomatlan
# Processing Record 2 of Set 13 | myaundzha
# Processing Record 3 of Set 13 | poroshkovo
# Processing Record 4 of Set 13 | puerto leguizamo
# Processing Record 5 of Set 13 | rawson
# Processing Record 6 of Set 13 | labuan
# Processing Record 7 of Set 13 | ulaangom
# Processing Record 8 of Set 13 | bocaiuva
# Processing Record 9 of Set 13 | san borja
# Processing Record 10 of Set 13 | vengerovo
# Processing Record 11 of Set 13 | ladario
# Processing Record 12 of Set 13 | mielec
# Processing Record 13 of Set 13 | champerico
# Processing Record 14 of Set 13 | alice springs
# Processing Record 15 of Set 13 | pallasovka
# Processing Record 16 of Set 13 | dillon
# Processing Record 17 of Set 13 | tarpon springs
# Processing Record 18 of Set 13 | mukhen
# Processing Record 19 of Set 13 | neftcala
# Processing Record 20 of Set 13 | puri
# Processing Record 21 of Set 13 | coahuayana
# Processing Record 22 of Set 13 | saint anthony
# Processing Record 23 of Set 13 | los llanos de aridane
# Processing Record 24 of Set 13 | mogadishu
# Processing Record 25 of Set 13 | sisophon
# Processing Record 26 of Set 13 | santa rosa
# Processing Record 27 of Set 13 | den helder
# Processing Record 28 of Set 13 | valparai
# Processing Record 29 of Set 13 | malinovskiy
# Processing Record 30 of Set 13 | baiyin
# Processing Record 31 of Set 13 | tyret pervaya
# Processing Record 32 of Set 13 | gap
# Processing Record 33 of Set 13 | dutse
# Processing Record 34 of Set 13 | sitka
# Processing Record 35 of Set 13 | tabasco
# Processing Record 36 of Set 13 | saint-louis
# Processing Record 37 of Set 13 | tautira
# Processing Record 38 of Set 13 | kisangani
# Processing Record 39 of Set 13 | terrasini
# Processing Record 40 of Set 13 | jardim
# Processing Record 41 of Set 13 | pringsewu
# Processing Record 42 of Set 13 | newry
# Processing Record 43 of Set 13 | yenagoa
# Processing Record 44 of Set 13 | coihaique
# Processing Record 45 of Set 13 | palana
# Processing Record 46 of Set 13 | kapit
# Processing Record 47 of Set 13 | adwa
# Processing Record 48 of Set 13 | candawaga
# City not found. Skipping...
# Processing Record 49 of Set 13 | wanaka
# Processing Record 50 of Set 13 | melfort
# Processing Record 1 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 2 of Set 14 | great falls
# Processing Record 3 of Set 14 | west bay
# Processing Record 4 of Set 14 | joshimath
# Processing Record 5 of Set 14 | djambala
# Processing Record 6 of Set 14 | norden
# Processing Record 7 of Set 14 | naifaru
# Processing Record 8 of Set 14 | san pedro
# Processing Record 9 of Set 14 | beloha
# Processing Record 10 of Set 14 | rusera
# Processing Record 11 of Set 14 | stanislav
# Processing Record 12 of Set 14 | baghdad
# Processing Record 13 of Set 14 | pajusti
# Processing Record 14 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 14 | mankono
# Processing Record 16 of Set 14 | davidson
# Processing Record 17 of Set 14 | santa cruz de la palma
# Processing Record 18 of Set 14 | parintins
# Processing Record 19 of Set 14 | san matias
# Processing Record 20 of Set 14 | tadine
# Processing Record 21 of Set 14 | seinajoki
# Processing Record 22 of Set 14 | kozyatyn
# Processing Record 23 of Set 14 | ballina
# Processing Record 24 of Set 14 | mmathubudukwane
# Processing Record 25 of Set 14 | ust-kuyga
# Processing Record 26 of Set 14 | namibe
# Processing Record 27 of Set 14 | florence
# Processing Record 28 of Set 14 | marzuq
# Processing Record 29 of Set 14 | segou
# Processing Record 30 of Set 14 | soyo
# Processing Record 31 of Set 14 | capaci
# Processing Record 32 of Set 14 | krasnoselkup
# Processing Record 33 of Set 14 | san quintin
# Processing Record 34 of Set 14 | nobres
# Processing Record 35 of Set 14 | sambo creek
# Processing Record 36 of Set 14 | manono
# Processing Record 37 of Set 14 | san juan
# Processing Record 38 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 14 | papara
# Processing Record 40 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 14 | derzhavinsk
# Processing Record 42 of Set 14 | kupang
# Processing Record 43 of Set 14 | canto do buriti
# Processing Record 44 of Set 14 | lagunas
# Processing Record 45 of Set 14 | sahuaripa
# Processing Record 46 of Set 14 | mandan
# Processing Record 47 of Set 14 | sayabec
# City not found. Skipping...
# Processing Record 48 of Set 14 | fairbanks
# Processing Record 49 of Set 14 | kijang
# Processing Record 50 of Set 14 | sivaki
# Processing Record 1 of Set 15 | sambava
# Processing Record 2 of Set 15 | ada
# Processing Record 3 of Set 15 | visby
# Processing Record 4 of Set 15 | alta floresta
# Processing Record 5 of Set 15 | panguna
# Processing Record 6 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 7 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 15 | santa cruz de tenerife
# Processing Record 9 of Set 15 | senador jose porfirio
# Processing Record 10 of Set 15 | rumoi
# Processing Record 11 of Set 15 | lerwick
# Processing Record 12 of Set 15 | yumen
# Processing Record 13 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 14 of Set 15 | leh
# Processing Record 15 of Set 15 | halifax
# Processing Record 16 of Set 15 | jacareacanga
# Processing Record 17 of Set 15 | narsaq
# Processing Record 18 of Set 15 | kolokani
# Processing Record 19 of Set 15 | mountain home
# Processing Record 20 of Set 15 | itoman
# Processing Record 21 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 15 | caconda
# Processing Record 23 of Set 15 | shiyan
# Processing Record 24 of Set 15 | grand-santi
# Processing Record 25 of Set 15 | camacha
# Processing Record 26 of Set 15 | bahia blanca
# Processing Record 27 of Set 15 | erenhot
# Processing Record 28 of Set 15 | kuryk
# Processing Record 29 of Set 15 | gagino
# Processing Record 30 of Set 15 | manggar
# Processing Record 31 of Set 15 | flinders
# Processing Record 32 of Set 15 | sinop
# Processing Record 33 of Set 15 | ornskoldsvik
# Processing Record 34 of Set 15 | spornoye
# Processing Record 35 of Set 15 | kushima
# Processing Record 36 of Set 15 | lysyanka
# Processing Record 37 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 15 | asten
# Processing Record 39 of Set 15 | acarau
# Processing Record 40 of Set 15 | mawlaik
# Processing Record 41 of Set 15 | kingussie
# Processing Record 42 of Set 15 | vila franca do campo
# Processing Record 43 of Set 15 | laje
# Processing Record 44 of Set 15 | waddan
# Processing Record 45 of Set 15 | goundam
# Processing Record 46 of Set 15 | valparaiso
# Processing Record 47 of Set 15 | te anau
# Processing Record 48 of Set 15 | port moresby
# Processing Record 49 of Set 15 | newport
# Processing Record 50 of Set 15 | gigmoto
# Processing Record 1 of Set 16 | lalitpur
# Processing Record 2 of Set 16 | jevargi
# Processing Record 3 of Set 16 | barcelona
# Processing Record 4 of Set 16 | porto de moz
# Processing Record 5 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 16 | san gabriel
# Processing Record 7 of Set 16 | luwuk
# Processing Record 8 of Set 16 | ahuimanu
# Processing Record 9 of Set 16 | karkaralinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint George      US  37.1041 -113.5841     72.00        24           1
# 1    Turukhansk      RU  65.8167   87.9833     -6.72       100         100
# 2    Carutapera      BR  -1.1950  -46.0200     77.72        88          88
# 3        Faanui      PF -16.4833 -151.7500     82.62        73          26
# 4       Rikitea      PF -23.1203 -134.9692     79.41        70           4
# 5    Zaplavnoye      RU  48.7048   45.0229     33.01        80           0
# 6    Georgetown      MY   5.4112  100.3354     80.01        94          20
# 7    Bredasdorp      ZA -34.5322   20.0403     62.60        82         100
# 8       Qaanaaq      GL  77.4840  -69.3632    -17.82        81          70
# 9       Tondano      ID   1.3038  124.9112     77.00        94          40
#
#    Wind Speed Current Description
# 0        4.61           clear sky
# 1        2.06     overcast clouds
# 2        6.78     overcast clouds
# 3       22.62    scattered clouds
# 4       15.14           clear sky
# 5        8.95           clear sky
# 6        2.30          light rain
# 7       11.50     overcast clouds
# 8        5.14       broken clouds
# 9        1.14       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label = "City ID")
