# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90,high=90,size=2000)
lngs=np.random.uniform(low=-180,high=180,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f186aa03fc9f35ac9338a77c0bfe069

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City":city.title(),
                          "Country": city_country,
                         "Lat":city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed":city_wind,
                         "Current Description":city_weather_description})

# If an error is experienced, skip the city.   
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ostrovnoy
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | syracuse
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | grand gaube
# Processing Record 12 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | mitsamiouli
# Processing Record 15 of Set 1 | mao
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | kargasok
# Processing Record 18 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | dryden
# Processing Record 27 of Set 1 | akyab
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | los llanos de aridane
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | nuuk
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | nome
# Processing Record 35 of Set 1 | neijiang
# Processing Record 36 of Set 1 | oudtshoorn
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | san vicente
# Processing Record 39 of Set 1 | aginskoye
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | chicama
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | wa
# City not found. Skipping...
# Processing Record 46 of Set 1 | mgandu
# Processing Record 47 of Set 1 | touros
# Processing Record 48 of Set 1 | panguna
# Processing Record 49 of Set 1 | camacha
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | manbij
# Processing Record 3 of Set 2 | kyshtovka
# Processing Record 4 of Set 2 | sept-iles
# Processing Record 5 of Set 2 | vanimo
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | elko
# Processing Record 8 of Set 2 | mataram
# Processing Record 9 of Set 2 | paamiut
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | hambantota
# Processing Record 12 of Set 2 | amalapuram
# Processing Record 13 of Set 2 | tefe
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | vao
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | shu
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | yatou
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | rijeka
# Processing Record 26 of Set 2 | hualmay
# Processing Record 27 of Set 2 | oranjestad
# Processing Record 28 of Set 2 | udachnyy
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | nchelenge
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | san jeronimo
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | viedma
# Processing Record 43 of Set 2 | vestmannaeyjar
# Processing Record 44 of Set 2 | mehamn
# Processing Record 45 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 46 of Set 2 | namatanai
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | jalu
# Processing Record 49 of Set 2 | muros
# Processing Record 50 of Set 2 | malatya
# Processing Record 1 of Set 3 | statesville
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | cockburn town
# Processing Record 4 of Set 3 | taltal
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | wattegama
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | itapeva
# Processing Record 10 of Set 3 | sechura
# Processing Record 11 of Set 3 | bacalar
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | naze
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | betanzos
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | mount darwin
# Processing Record 19 of Set 3 | gazimurskiy zavod
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | the valley
# Processing Record 22 of Set 3 | quatre cocos
# Processing Record 23 of Set 3 | bulaevo
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | caravelas
# Processing Record 26 of Set 3 | marfino
# Processing Record 27 of Set 3 | north bend
# Processing Record 28 of Set 3 | dogondoutchi
# Processing Record 29 of Set 3 | morozovsk
# Processing Record 30 of Set 3 | samarai
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | riyadh
# Processing Record 36 of Set 3 | victoria
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | payo
# Processing Record 39 of Set 3 | juigalpa
# Processing Record 40 of Set 3 | areia branca
# Processing Record 41 of Set 3 | presidencia roque saenz pena
# Processing Record 42 of Set 3 | alice springs
# Processing Record 43 of Set 3 | san cristobal
# Processing Record 44 of Set 3 | bilma
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | alyangula
# Processing Record 49 of Set 3 | shelburne
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | manga
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | aklavik
# Processing Record 5 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 4 | toamasina
# Processing Record 7 of Set 4 | rodas
# Processing Record 8 of Set 4 | yumen
# Processing Record 9 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 4 | warrington
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | merke
# Processing Record 13 of Set 4 | srandakan
# Processing Record 14 of Set 4 | eureka
# Processing Record 15 of Set 4 | cape town
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | ojinaga
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | nemuro
# Processing Record 20 of Set 4 | sainte-suzanne
# Processing Record 21 of Set 4 | high level
# Processing Record 22 of Set 4 | mingguang
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | anau
# Processing Record 25 of Set 4 | saint-pierre
# Processing Record 26 of Set 4 | pervomayskoye
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | caruaru
# Processing Record 29 of Set 4 | praia
# Processing Record 30 of Set 4 | yerbogachen
# Processing Record 31 of Set 4 | ayan
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | ormara
# Processing Record 34 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 4 | ribeira brava
# Processing Record 36 of Set 4 | pangkalanbuun
# Processing Record 37 of Set 4 | teacapan
# Processing Record 38 of Set 4 | inhambane
# Processing Record 39 of Set 4 | ust-barguzin
# Processing Record 40 of Set 4 | zhigansk
# Processing Record 41 of Set 4 | mahebourg
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | somerset
# Processing Record 44 of Set 4 | kazanskaya
# Processing Record 45 of Set 4 | ust-shonosha
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 4 | abu samrah
# Processing Record 50 of Set 4 | michigan city
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | miraflores
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | roald
# Processing Record 5 of Set 5 | rehoboth
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | prainha
# Processing Record 8 of Set 5 | pangnirtung
# Processing Record 9 of Set 5 | nouadhibou
# Processing Record 10 of Set 5 | almoloya
# Processing Record 11 of Set 5 | kushima
# Processing Record 12 of Set 5 | caiaponia
# Processing Record 13 of Set 5 | xiongzhou
# Processing Record 14 of Set 5 | vostok
# Processing Record 15 of Set 5 | winnemucca
# Processing Record 16 of Set 5 | divnomorskoye
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | urukh
# Processing Record 19 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 5 | ancud
# Processing Record 21 of Set 5 | college
# Processing Record 22 of Set 5 | abu dhabi
# Processing Record 23 of Set 5 | krasnoselkup
# Processing Record 24 of Set 5 | rio grande
# Processing Record 25 of Set 5 | mount isa
# Processing Record 26 of Set 5 | felipe carrillo puerto
# Processing Record 27 of Set 5 | martapura
# Processing Record 28 of Set 5 | plettenberg bay
# Processing Record 29 of Set 5 | mizdah
# Processing Record 30 of Set 5 | hobart
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | tiarei
# Processing Record 33 of Set 5 | te anau
# Processing Record 34 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 5 | severodvinsk
# Processing Record 36 of Set 5 | shizunai
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | hamilton
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | burnie
# Processing Record 41 of Set 5 | fayaoue
# Processing Record 42 of Set 5 | buraydah
# Processing Record 43 of Set 5 | lakes entrance
# Processing Record 44 of Set 5 | ballina
# Processing Record 45 of Set 5 | okhotsk
# Processing Record 46 of Set 5 | clovis
# Processing Record 47 of Set 5 | freeport
# Processing Record 48 of Set 5 | harlingen
# Processing Record 49 of Set 5 | kodiak
# Processing Record 50 of Set 5 | port augusta
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | saskylakh
# Processing Record 3 of Set 6 | bayan
# Processing Record 4 of Set 6 | klang
# Processing Record 5 of Set 6 | natubleng
# Processing Record 6 of Set 6 | roebourne
# Processing Record 7 of Set 6 | half moon bay
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | nara
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 6 | onega
# Processing Record 13 of Set 6 | villazon
# Processing Record 14 of Set 6 | vytegra
# Processing Record 15 of Set 6 | sembe
# Processing Record 16 of Set 6 | oktyabrskoye
# Processing Record 17 of Set 6 | leh
# Processing Record 18 of Set 6 | thunder bay
# Processing Record 19 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 6 | hofn
# Processing Record 21 of Set 6 | shahabad
# Processing Record 22 of Set 6 | gloversville
# Processing Record 23 of Set 6 | awjilah
# Processing Record 24 of Set 6 | chuy
# Processing Record 25 of Set 6 | abha
# Processing Record 26 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | channel-port aux basques
# Processing Record 29 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | hovd
# Processing Record 34 of Set 6 | nishihara
# Processing Record 35 of Set 6 | kruisfontein
# Processing Record 36 of Set 6 | ust-koksa
# Processing Record 37 of Set 6 | rosarito
# Processing Record 38 of Set 6 | diego de almagro
# Processing Record 39 of Set 6 | mandalgovi
# Processing Record 40 of Set 6 | marsa matruh
# Processing Record 41 of Set 6 | fort nelson
# Processing Record 42 of Set 6 | benguela
# Processing Record 43 of Set 6 | jardim
# Processing Record 44 of Set 6 | prabumulih
# Processing Record 45 of Set 6 | krutinka
# Processing Record 46 of Set 6 | kolokani
# Processing Record 47 of Set 6 | husavik
# Processing Record 48 of Set 6 | le port
# Processing Record 49 of Set 6 | dudinka
# Processing Record 50 of Set 6 | lompoc
# Processing Record 1 of Set 7 | zhicheng
# Processing Record 2 of Set 7 | port-gentil
# Processing Record 3 of Set 7 | loikaw
# Processing Record 4 of Set 7 | bambous virieux
# Processing Record 5 of Set 7 | beloha
# Processing Record 6 of Set 7 | maloy
# Processing Record 7 of Set 7 | bethel
# Processing Record 8 of Set 7 | taguatinga
# Processing Record 9 of Set 7 | dukat
# Processing Record 10 of Set 7 | alofi
# Processing Record 11 of Set 7 | hay river
# Processing Record 12 of Set 7 | banda aceh
# Processing Record 13 of Set 7 | namuac
# Processing Record 14 of Set 7 | hami
# Processing Record 15 of Set 7 | faanui
# Processing Record 16 of Set 7 | puerto madryn
# Processing Record 17 of Set 7 | hashtrud
# Processing Record 18 of Set 7 | necochea
# Processing Record 19 of Set 7 | gat
# Processing Record 20 of Set 7 | sinnamary
# Processing Record 21 of Set 7 | mogok
# Processing Record 22 of Set 7 | aktash
# Processing Record 23 of Set 7 | praya
# Processing Record 24 of Set 7 | calvinia
# Processing Record 25 of Set 7 | tautira
# Processing Record 26 of Set 7 | odweyne
# Processing Record 27 of Set 7 | iqaluit
# Processing Record 28 of Set 7 | kununurra
# Processing Record 29 of Set 7 | launceston
# Processing Record 30 of Set 7 | yanam
# Processing Record 31 of Set 7 | byron bay
# Processing Record 32 of Set 7 | ayios yeoryios
# Processing Record 33 of Set 7 | veletma
# City not found. Skipping...
# Processing Record 34 of Set 7 | frederico westphalen
# Processing Record 35 of Set 7 | richards bay
# Processing Record 36 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | manono
# Processing Record 39 of Set 7 | sur
# Processing Record 40 of Set 7 | salalah
# Processing Record 41 of Set 7 | healdsburg
# Processing Record 42 of Set 7 | kielce
# Processing Record 43 of Set 7 | adrar
# Processing Record 44 of Set 7 | macusani
# Processing Record 45 of Set 7 | the pas
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | kyra
# Processing Record 48 of Set 7 | songkhla
# Processing Record 49 of Set 7 | port blair
# Processing Record 50 of Set 7 | vardo
# Processing Record 1 of Set 8 | jacmel
# Processing Record 2 of Set 8 | la peca
# Processing Record 3 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 8 | jieshi
# Processing Record 5 of Set 8 | anori
# Processing Record 6 of Set 8 | carupano
# Processing Record 7 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 8 | zabol
# Processing Record 9 of Set 8 | kemi
# Processing Record 10 of Set 8 | presque isle
# Processing Record 11 of Set 8 | gorin
# Processing Record 12 of Set 8 | kargil
# Processing Record 13 of Set 8 | nagapattinam
# Processing Record 14 of Set 8 | san policarpo
# Processing Record 15 of Set 8 | egvekinot
# Processing Record 16 of Set 8 | lanivtsi
# Processing Record 17 of Set 8 | tornabe
# Processing Record 18 of Set 8 | brownwood
# Processing Record 19 of Set 8 | bay roberts
# Processing Record 20 of Set 8 | denpasar
# Processing Record 21 of Set 8 | makakilo city
# Processing Record 22 of Set 8 | quelimane
# Processing Record 23 of Set 8 | karad
# Processing Record 24 of Set 8 | dwarka
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | rancho palos verdes
# Processing Record 27 of Set 8 | dubbo
# Processing Record 28 of Set 8 | davila
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | pevek
# Processing Record 31 of Set 8 | turbat
# Processing Record 32 of Set 8 | destin
# Processing Record 33 of Set 8 | mezen
# Processing Record 34 of Set 8 | anadyr
# Processing Record 35 of Set 8 | taraza
# Processing Record 36 of Set 8 | malanje
# Processing Record 37 of Set 8 | charleville-mezieres
# Processing Record 38 of Set 8 | macklin
# Processing Record 39 of Set 8 | rockport
# Processing Record 40 of Set 8 | sisimiut
# Processing Record 41 of Set 8 | westport
# Processing Record 42 of Set 8 | castelo do piaui
# Processing Record 43 of Set 8 | port-de-bouc
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 8 | dinghai
# Processing Record 47 of Set 8 | manicore
# Processing Record 48 of Set 8 | biak
# Processing Record 49 of Set 8 | tucurui
# Processing Record 50 of Set 8 | derzhavinsk
# Processing Record 1 of Set 9 | mugan
# Processing Record 2 of Set 9 | saint-augustin
# Processing Record 3 of Set 9 | surgana
# Processing Record 4 of Set 9 | mayo
# Processing Record 5 of Set 9 | quime
# Processing Record 6 of Set 9 | skoghall
# Processing Record 7 of Set 9 | murdochville
# Processing Record 8 of Set 9 | kisangani
# Processing Record 9 of Set 9 | mersin
# Processing Record 10 of Set 9 | massaguet
# Processing Record 11 of Set 9 | batagay-alyta
# Processing Record 12 of Set 9 | lodja
# Processing Record 13 of Set 9 | mayumba
# Processing Record 14 of Set 9 | kangaatsiaq
# Processing Record 15 of Set 9 | nogliki
# Processing Record 16 of Set 9 | leningradskiy
# Processing Record 17 of Set 9 | rocha
# Processing Record 18 of Set 9 | vung tau
# Processing Record 19 of Set 9 | olafsvik
# Processing Record 20 of Set 9 | weatherford
# Processing Record 21 of Set 9 | darhan
# Processing Record 22 of Set 9 | cayenne
# Processing Record 23 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 24 of Set 9 | kemin
# Processing Record 25 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 9 | kyren
# Processing Record 27 of Set 9 | nizwa
# Processing Record 28 of Set 9 | salinopolis
# Processing Record 29 of Set 9 | ponta delgada
# Processing Record 30 of Set 9 | arti
# Processing Record 31 of Set 9 | souillac
# Processing Record 32 of Set 9 | bilibino
# Processing Record 33 of Set 9 | motygino
# Processing Record 34 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 9 | contamana
# Processing Record 36 of Set 9 | zemio
# Processing Record 37 of Set 9 | yelkhovka
# Processing Record 38 of Set 9 | ulladulla
# Processing Record 39 of Set 9 | siilinjarvi
# Processing Record 40 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 41 of Set 9 | ejea de los caballeros
# Processing Record 42 of Set 9 | teguise
# Processing Record 43 of Set 9 | christchurch
# Processing Record 44 of Set 9 | katsuura
# Processing Record 45 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 9 | benghazi
# Processing Record 48 of Set 9 | jiexiu
# Processing Record 49 of Set 9 | bardiyah
# Processing Record 50 of Set 9 | maracaibo
# Processing Record 1 of Set 10 | tiznit
# Processing Record 2 of Set 10 | coihaique
# Processing Record 3 of Set 10 | kapoeta
# Processing Record 4 of Set 10 | baffa
# Processing Record 5 of Set 10 | marsh harbour
# Processing Record 6 of Set 10 | margate
# Processing Record 7 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 10 | kanniyakumari
# Processing Record 9 of Set 10 | corner brook
# Processing Record 10 of Set 10 | sampang
# Processing Record 11 of Set 10 | ixtapa
# Processing Record 12 of Set 10 | lom
# Processing Record 13 of Set 10 | nanakuli
# Processing Record 14 of Set 10 | port hardy
# Processing Record 15 of Set 10 | provideniya
# Processing Record 16 of Set 10 | guaimaca
# Processing Record 17 of Set 10 | moa
# Processing Record 18 of Set 10 | yichun
# Processing Record 19 of Set 10 | namibe
# Processing Record 20 of Set 10 | mugur-aksy
# Processing Record 21 of Set 10 | rawson
# Processing Record 22 of Set 10 | palmer
# Processing Record 23 of Set 10 | astoria
# Processing Record 24 of Set 10 | eldoret
# Processing Record 25 of Set 10 | padang
# Processing Record 26 of Set 10 | bonavista
# Processing Record 27 of Set 10 | garden city
# Processing Record 28 of Set 10 | grand-santi
# Processing Record 29 of Set 10 | curuguaty
# Processing Record 30 of Set 10 | bemidji
# Processing Record 31 of Set 10 | kahului
# Processing Record 32 of Set 10 | koygorodok
# Processing Record 33 of Set 10 | ulaangom
# Processing Record 34 of Set 10 | kieta
# Processing Record 35 of Set 10 | haines junction
# Processing Record 36 of Set 10 | nau
# Processing Record 37 of Set 10 | mecca
# Processing Record 38 of Set 10 | barkhan
# Processing Record 39 of Set 10 | knysna
# Processing Record 40 of Set 10 | port macquarie
# Processing Record 41 of Set 10 | luanda
# Processing Record 42 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 10 | la ronge
# Processing Record 44 of Set 10 | elbistan
# Processing Record 45 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 10 | kavaratti
# Processing Record 47 of Set 10 | poum
# Processing Record 48 of Set 10 | borba
# Processing Record 49 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 10 | manggar
# Processing Record 1 of Set 11 | narrabri
# Processing Record 2 of Set 11 | galle
# Processing Record 3 of Set 11 | sibu
# Processing Record 4 of Set 11 | flinders
# Processing Record 5 of Set 11 | kokopo
# Processing Record 6 of Set 11 | kawalu
# Processing Record 7 of Set 11 | dunedin
# Processing Record 8 of Set 11 | rincon
# Processing Record 9 of Set 11 | betong
# Processing Record 10 of Set 11 | excelsior springs
# Processing Record 11 of Set 11 | hayden
# Processing Record 12 of Set 11 | sorong
# Processing Record 13 of Set 11 | santiago
# Processing Record 14 of Set 11 | pangai
# Processing Record 15 of Set 11 | henties bay
# Processing Record 16 of Set 11 | porto velho
# Processing Record 17 of Set 11 | palm beach
# Processing Record 18 of Set 11 | burica
# City not found. Skipping...
# Processing Record 19 of Set 11 | sainte-marie
# Processing Record 20 of Set 11 | nakhon sawan
# Processing Record 21 of Set 11 | paita
# Processing Record 22 of Set 11 | marsaxlokk
# Processing Record 23 of Set 11 | garissa
# Processing Record 24 of Set 11 | pericos
# Processing Record 25 of Set 11 | hereford
# Processing Record 26 of Set 11 | acarau
# Processing Record 27 of Set 11 | wagar
# Processing Record 28 of Set 11 | caraquet
# Processing Record 29 of Set 11 | constitucion
# Processing Record 30 of Set 11 | bani
# Processing Record 31 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 11 | macia
# Processing Record 33 of Set 11 | wittmund
# Processing Record 34 of Set 11 | tacuarembo
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | vrangel
# Processing Record 37 of Set 11 | dingle
# Processing Record 38 of Set 11 | kalabo
# Processing Record 39 of Set 11 | winton
# Processing Record 40 of Set 11 | narsaq
# Processing Record 41 of Set 11 | lewiston
# Processing Record 42 of Set 11 | pisco
# Processing Record 43 of Set 11 | kysyl-syr
# Processing Record 44 of Set 11 | ende
# Processing Record 45 of Set 11 | tenenkou
# Processing Record 46 of Set 11 | agadez
# Processing Record 47 of Set 11 | durusu
# Processing Record 48 of Set 11 | langsa
# Processing Record 49 of Set 11 | muravlenko
# Processing Record 50 of Set 11 | aljezur
# Processing Record 1 of Set 12 | cap-aux-meules
# Processing Record 2 of Set 12 | murmashi
# Processing Record 3 of Set 12 | miyazu
# Processing Record 4 of Set 12 | nivala
# Processing Record 5 of Set 12 | nata
# Processing Record 6 of Set 12 | hirara
# Processing Record 7 of Set 12 | qasigiannguit
# Processing Record 8 of Set 12 | logan
# Processing Record 9 of Set 12 | woodward
# Processing Record 10 of Set 12 | hanzhong
# Processing Record 11 of Set 12 | severo-yeniseyskiy
# Processing Record 12 of Set 12 | pingyin
# Processing Record 13 of Set 12 | skibotn
# Processing Record 14 of Set 12 | davidson
# Processing Record 15 of Set 12 | masterton
# Processing Record 16 of Set 12 | saldanha
# Processing Record 17 of Set 12 | qixia
# Processing Record 18 of Set 12 | tecozautla
# Processing Record 19 of Set 12 | havoysund
# Processing Record 20 of Set 12 | bitam
# Processing Record 21 of Set 12 | dzaoudzi
# Processing Record 22 of Set 12 | scarborough
# Processing Record 23 of Set 12 | la rioja
# Processing Record 24 of Set 12 | deputatskiy
# Processing Record 25 of Set 12 | nelson bay
# Processing Record 26 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 12 | ternate
# Processing Record 28 of Set 12 | vitim
# Processing Record 29 of Set 12 | cheney
# Processing Record 30 of Set 12 | ostersund
# Processing Record 31 of Set 12 | sapele
# Processing Record 32 of Set 12 | svetlaya
# Processing Record 33 of Set 12 | lima
# Processing Record 34 of Set 12 | jimma
# Processing Record 35 of Set 12 | flin flon
# Processing Record 36 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 12 | karpathos
# Processing Record 38 of Set 12 | orje
# Processing Record 39 of Set 12 | kosh-agach
# Processing Record 40 of Set 12 | prince george
# Processing Record 41 of Set 12 | cabedelo
# Processing Record 42 of Set 12 | chermoz
# Processing Record 43 of Set 12 | orillia
# Processing Record 44 of Set 12 | yining
# Processing Record 45 of Set 12 | carora
# Processing Record 46 of Set 12 | visby
# Processing Record 47 of Set 12 | hasaki
# Processing Record 48 of Set 12 | urumqi
# Processing Record 49 of Set 12 | fairlie
# Processing Record 50 of Set 12 | lorengau
# Processing Record 1 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 13 | yar-sale
# Processing Record 3 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 13 | west hartford
# Processing Record 5 of Set 13 | cabo san lucas
# Processing Record 6 of Set 13 | warrnambool
# Processing Record 7 of Set 13 | libertador general san martin
# Processing Record 8 of Set 13 | la asuncion
# Processing Record 9 of Set 13 | bolitoc
# Processing Record 10 of Set 13 | saint-francois
# Processing Record 11 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 12 of Set 13 | camopi
# Processing Record 13 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 13 | valparaiso
# Processing Record 15 of Set 13 | kilrush
# Processing Record 16 of Set 13 | norman wells
# Processing Record 17 of Set 13 | tecoanapa
# Processing Record 18 of Set 13 | springfield
# Processing Record 19 of Set 13 | genhe
# Processing Record 20 of Set 13 | grindavik
# Processing Record 21 of Set 13 | prien
# Processing Record 22 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 13 | lukang
# Processing Record 24 of Set 13 | akdepe
# Processing Record 25 of Set 13 | pueblo nuevo
# Processing Record 26 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 27 of Set 13 | sao joao da barra
# Processing Record 28 of Set 13 | tessalit
# Processing Record 29 of Set 13 | khasan
# Processing Record 30 of Set 13 | roma
# Processing Record 31 of Set 13 | longyearbyen
# Processing Record 32 of Set 13 | ayagoz
# Processing Record 33 of Set 13 | russell
# Processing Record 34 of Set 13 | grande prairie
# Processing Record 35 of Set 13 | kirakira
# Processing Record 36 of Set 13 | acapulco
# Processing Record 37 of Set 13 | sault sainte marie
# Processing Record 38 of Set 13 | solnechnyy
# Processing Record 39 of Set 13 | lundazi
# Processing Record 40 of Set 13 | zomin
# Processing Record 41 of Set 13 | kaduqli
# Processing Record 42 of Set 13 | imeni stepana razina
# Processing Record 43 of Set 13 | puerto carreno
# Processing Record 44 of Set 13 | katobu
# Processing Record 45 of Set 13 | aktas
# Processing Record 46 of Set 13 | gardner
# Processing Record 47 of Set 13 | korsakov
# Processing Record 48 of Set 13 | freetown
# Processing Record 49 of Set 13 | lubaczow
# Processing Record 50 of Set 13 | noumea
# Processing Record 1 of Set 14 | jilotepec
# Processing Record 2 of Set 14 | lishui
# Processing Record 3 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 14 | nianzishan
# Processing Record 5 of Set 14 | portland
# Processing Record 6 of Set 14 | lasa
# Processing Record 7 of Set 14 | chapais
# Processing Record 8 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 9 of Set 14 | vila
# Processing Record 10 of Set 14 | dharchula
# Processing Record 11 of Set 14 | santa cruz
# Processing Record 12 of Set 14 | cap malheureux
# Processing Record 13 of Set 14 | esna
# Processing Record 14 of Set 14 | sioux lookout
# Processing Record 15 of Set 14 | sosnogorsk
# Processing Record 16 of Set 14 | motala
# Processing Record 17 of Set 14 | san fernando
# Processing Record 18 of Set 14 | suez
# Processing Record 19 of Set 14 | zavyalovo
# Processing Record 20 of Set 14 | pangody
# Processing Record 21 of Set 14 | polis
# Processing Record 22 of Set 14 | itarema
# Processing Record 23 of Set 14 | ilebo
# Processing Record 24 of Set 14 | macau
# Processing Record 25 of Set 14 | farah
# Processing Record 26 of Set 14 | sistranda
# Processing Record 27 of Set 14 | lata
# Processing Record 28 of Set 14 | fenoarivo
# Processing Record 29 of Set 14 | gamba
# Processing Record 30 of Set 14 | eirunepe
# Processing Record 31 of Set 14 | jiuquan
# Processing Record 32 of Set 14 | evensk
# Processing Record 33 of Set 14 | filadelfia
# Processing Record 34 of Set 14 | tual
# Processing Record 35 of Set 14 | sun valley
# Processing Record 36 of Set 14 | plock
# Processing Record 37 of Set 14 | price
# Processing Record 38 of Set 14 | andenes
# Processing Record 39 of Set 14 | san carlos de bariloche
# Processing Record 40 of Set 14 | lubao
# Processing Record 41 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 14 | tynda
# Processing Record 43 of Set 14 | enshi
# Processing Record 44 of Set 14 | saint-georges
# Processing Record 45 of Set 14 | palmeira
# Processing Record 46 of Set 14 | beysehir
# Processing Record 47 of Set 14 | porto murtinho
# Processing Record 48 of Set 14 | teruel
# Processing Record 49 of Set 14 | pasni
# Processing Record 50 of Set 14 | asau
# Processing Record 1 of Set 15 | muzquiz
# City not found. Skipping...
# Processing Record 2 of Set 15 | alakurtti
# Processing Record 3 of Set 15 | qaqortoq
# Processing Record 4 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 5 of Set 15 | nurota
# Processing Record 6 of Set 15 | san matias
# Processing Record 7 of Set 15 | omboue
# Processing Record 8 of Set 15 | chabahar
# Processing Record 9 of Set 15 | sfantu gheorghe
# Processing Record 10 of Set 15 | bure
# Processing Record 11 of Set 15 | nyaunglebin
# Processing Record 12 of Set 15 | mugumu
# Processing Record 13 of Set 15 | gikongoro
# Processing Record 14 of Set 15 | xique-xique
# Processing Record 15 of Set 15 | pingdu
# Processing Record 16 of Set 15 | sherbakul
# Processing Record 17 of Set 15 | aron
# Processing Record 18 of Set 15 | yeniseysk
# Processing Record 19 of Set 15 | aksu
# Processing Record 20 of Set 15 | svetlyy
# Processing Record 21 of Set 15 | kasempa
# Processing Record 22 of Set 15 | fare
# Processing Record 23 of Set 15 | chkalovsk
# Processing Record 24 of Set 15 | sabzevar
# Processing Record 25 of Set 15 | mareeba
# Processing Record 26 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 27 of Set 15 | zarubino
# Processing Record 28 of Set 15 | auki
# Processing Record 29 of Set 15 | meulaboh
# Processing Record 30 of Set 15 | bundaberg
# Processing Record 31 of Set 15 | kabare
# Processing Record 32 of Set 15 | bowen
# Processing Record 33 of Set 15 | arraias
# Processing Record 34 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 15 | veraval
# Processing Record 36 of Set 15 | sampit
# Processing Record 37 of Set 15 | bandarbeyla
# Processing Record 38 of Set 15 | hermosillo
# Processing Record 39 of Set 15 | pontes e lacerda
# Processing Record 40 of Set 15 | janossomorja
# Processing Record 41 of Set 15 | nalut
# Processing Record 42 of Set 15 | aguimes
# Processing Record 43 of Set 15 | uthal
# Processing Record 44 of Set 15 | svetlogorsk
# Processing Record 45 of Set 15 | pulsano
# Processing Record 46 of Set 15 | ugoofaaru
# Processing Record 47 of Set 15 | tilichiki
# Processing Record 48 of Set 15 | seagoville
# Processing Record 49 of Set 15 | waingapu
# Processing Record 50 of Set 15 | klyuchi
# Processing Record 1 of Set 16 | miles city
# Processing Record 2 of Set 16 | haimen
# Processing Record 3 of Set 16 | juifang
# City not found. Skipping...
# Processing Record 4 of Set 16 | gizo
# Processing Record 5 of Set 16 | pocone
# Processing Record 6 of Set 16 | ahuimanu
# Processing Record 7 of Set 16 | gimli
# Processing Record 8 of Set 16 | ozinki
# Processing Record 9 of Set 16 | verkhoyansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ostrovnoy      RU  68.0531   39.5131     35.29        98         100
# 1      Thompson      CA  55.7435  -97.8558     28.40        43          75
# 2         Vaini      TO -21.2000 -175.2000     78.80        89          75
# 3  Saint George      US  37.1041 -113.5841     70.00        27           1
# 4     Hithadhoo      MV  -0.6000   73.0833     80.15        83         100
# 5     Fairbanks      US  64.8378 -147.7164     10.00        66           1
# 6         Airai      TL  -8.9266  125.4092     60.28        95         100
# 7      Syracuse      IT  37.0881   15.2792     59.00        82           0
# 8  Punta Arenas      CL -53.1500  -70.9167     55.40        41           0
# 9   Grand Gaube      MU -20.0064   57.6608     78.01        79           1
#
#    Wind Speed   Current Description
# 0       13.49       overcast clouds
# 1        6.91         broken clouds
# 2        9.22            light rain
# 3        3.44             clear sky
# 4       30.65  heavy intensity rain
# 5        5.75             clear sky
# 6        2.35       overcast clouds
# 7        9.22             clear sky
# 8       16.11             clear sky
# 9        2.24             clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
